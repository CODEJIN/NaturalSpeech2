# %%
import os
os.environ['CUDA_VISIBLE_DEVICES'] = '-1'
from Inference import Inferencer
import IPython.display as ipd

# %%
inferencer = Inferencer(
    hp_path= 'Hyper_Parameters.yaml',
    checkpoint_path= './results/LJ_230518/Checkpoint/S_45000.pt',
    batch_size= 8
    )
inferencer.model.diffusion.denoiser.remove_weight_norm()
# Out:
# C:\Users\codej\miniconda3\lib\site-packages\torch\functional.py:1728: UserWarning: torch.lu is deprecated in favor of torch.linalg.lu_factor / torch.linalg.lu_factor_ex and will be removed in a future PyTorch release.
# LU, pivots = torch.lu(A, compute_pivots)
# should be replaced with
# LU, pivots = torch.linalg.lu_factor(A, compute_pivots)
# and
# LU, pivots, info = torch.lu(A, compute_pivots, get_infos=True)
# should be replaced with
# LU, pivots, info = torch.linalg.lu_factor_ex(A, compute_pivots) (Triggered internally at C:\cb\pytorch_1000000000000\work\aten\src\ATen\native\BatchLinearAlgebra.cpp:2001.)
#   return torch._lu_with_info(A, pivot=pivot, check_errors=(not get_infos))
# 2023-05-18 19:07:43,587 (Inference:66) INFO: Checkpoint loaded at 45000 steps.

# %%
texts = [    
    'No pain, No gain.',
    'Don’t kill the goose that lays the golden eggs.'
    ]
references= ['Inference_Wav/p279_003_mic2.flac'] * len(texts)
ddim_steps = 100

# %%
audios = inferencer.Inference_Epoch(
    texts= texts,
    references= references,
    ddim_steps= ddim_steps
    )

for text, reference, audio in zip(texts, references, audios):
    print(text)
    print(reference)
    ipd.display(ipd.Audio(audio, rate= inferencer.hp.Sound.Sample_Rate))
    print()
# Out:
# [Inference]: 100%|███████████████████████████████████████████████████████████████████████| 1/1 [00:57<00:00, 57.65s/it]
# No pain, No gain.
# Inference_Wav/p279_003_mic2.flac
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>
# Don’t kill the goose that lays the golden eggs.
# Inference_Wav/p279_003_mic2.flac
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>
